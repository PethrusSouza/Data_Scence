# %% [markdown]
# <a href="https://colab.research.google.com/github/PethrusSouza/Data_Scence/blob/main/dados_vacinados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = pd.read_csv('http://dados.recife.pe.gov.br/dataset/f381d9ea-4839-44a6-b4fe-788239189900/resource/966e9c4c-df45-40d7-9c58-2f13c61a6d28/download/vacinados.csv', sep=';')

# %%
url2 = url.copy()

# %%
url3 = url

# %%
url
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
url2
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
url.head()
# Out:
#               cpf                           nome       sexo  \
# 0  ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1  ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4  ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
#
#                                    grupo  \
# 0  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1  TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 2                 TRABALHADORES DA SAÚDE
# 3                 TRABALHADORES DA SAÚDE
# 4                 TRABALHADORES DA SAÚDE
#
#                                               vacina         lote  dose  \
# 0  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)  219VCD270W    2.0
# 1  2 - CHADOX1NCOV-19 - OXFORD/ASTRAZENECA (FIOCRUZ)   216VCD206Z   1.0
# 2                 1 - CORONAVAC - SINOVAC (BUTANTAN)       210043   2.0
# ...

# %%
url2.tail()
# Out:
#                     cpf                        nome       sexo   grupo  \
# 3407293  ***.619.454-**  NECIRA FERREIRA DE SANTANA   FEMININO  IDOSOS
# 3407294  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407295  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407296  ***.705.064-**  SEVERINO MANOEL DE SANTANA  MASCULINO  IDOSOS
# 3407297             NaN                         NaN        NaN     NaN
#
#                                      vacina     lote  dose data_vacinacao  \
# 3407293              3 - COMIRNATY (PFIZER)   FF8848   3.0     2021-09-29
# 3407294  1 - CORONAVAC - SINOVAC (BUTANTAN)  210052A   2.0     2021-03-11
# 3407295              3 - COMIRNATY (PFIZER)   FF8848   3.0     2021-09-29
# 3407296  1 - CORONAVAC - SINOVAC (BUTANTAN)   210016   1.0     2021-02-17
# 3407297                                 NaN      NaN   NaN            NaN
#
#                                 local_vacinacao
# ...

# %%
coluna = url2["cpf"]
coluna
# Out:
# 0          ***.574.544-**
# 1          ***.574.544-**
# 2          ***.886.964-**
# 3          ***.886.964-**
# 4          ***.886.964-**
#                 ...
# 3407293    ***.619.454-**
# 3407294    ***.705.064-**
# 3407295    ***.705.064-**
# 3407296    ***.705.064-**
# 3407297               NaN
# Name: cpf, Length: 3407298, dtype: object

# %%
url2.isna()
# Out:
#            cpf   nome   sexo  grupo  vacina   lote   dose  data_vacinacao  \
# 0        False  False  False  False   False  False  False           False
# 1        False  False  False  False   False  False  False           False
# 2        False  False  False  False   False  False  False           False
# 3        False  False  False  False   False  False  False           False
# 4        False  False  False  False   False  False  False           False
# ...        ...    ...    ...    ...     ...    ...    ...             ...
# 3407293  False  False  False  False   False  False  False           False
# 3407294  False  False  False  False   False  False  False           False
# 3407295  False  False  False  False   False  False  False           False
# 3407296  False  False  False  False   False  False  False           False
# 3407297   True   True   True   True    True   True   True            True
#
#          local_vacinacao
# 0                  False
# 1                  False
# ...

# %%
url2.isna().sum()
# Out:
# cpf                4060
# nome                  1
# sexo                256
# grupo                 1
# vacina                1
# lote                 94
# dose                  1
# data_vacinacao        1
# local_vacinacao       1
# dtype: int64

# %%
selecao = url2 ["sexo"] == "MASCULINO"
homens_unicos = url2[selecao][["nome", "sexo"]]
homens_unicos
# Out:
#                                nome       sexo
# 0         AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1         AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 10            AANTONIO DE MELO LIMA  MASCULINO
# 11            AANTONIO DE MELO LIMA  MASCULINO
# 12            AANTONIO DE MELO LIMA  MASCULINO
# ...                             ...        ...
# 3407289       ZYON FERREIRA RIBEIRO  MASCULINO
# 3407290       ZYON FERREIRA RIBEIRO  MASCULINO
# 3407294  SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  SEVERINO MANOEL DE SANTANA  MASCULINO
#
# [1460003 rows x 2 columns]

# %%
homens_unicos["nome"].unique() #metodo unique apenas em series... 1 coluna
# Out:
# array(['AABAN VASCONCELOS ZYZZYAG', 'AANTONIO DE MELO LIMA',
#        'AARAO AATA LEAL GUIMARAES', ..., 'ZYMBELTH BARBOSA DA SILVA',
#        'ZYON ALECKSANO DE OLIVEIRA SILVA', 'ZYON FERREIRA RIBEIRO'],
#       dtype=object)

# %%
#quantos homens foram vacinados?
hs = homens_unicos.drop_duplicates()
hs
# Out:
#                                         nome       sexo
# 0                  AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 10                     AANTONIO DE MELO LIMA  MASCULINO
# 13                 AARAO AATA LEAL GUIMARAES  MASCULINO
# 15       AARÃO GONÇALVES DE OLIVEIRA BARRETO  MASCULINO
# 16        AARÃO JOSÉ CARNEIRO DE VASCONCELOS  MASCULINO
# ...                                      ...        ...
# 3407251       ZURY BENNY OLIVEIRA DE ALMEIDA  MASCULINO
# 3407273        ZWINGLIO OLIVEIRA ALBUQUERQUE  MASCULINO
# 3407281            ZYMBELTH BARBOSA DA SILVA  MASCULINO
# 3407287     ZYON ALECKSANO DE OLIVEIRA SILVA  MASCULINO
# 3407289                ZYON FERREIRA RIBEIRO  MASCULINO
#
# [612769 rows x 2 columns]

# %%
homem = hs.count()
homem
# Out:
# nome    612769
# sexo    612769
# dtype: int64

# %%
url2.columns.to_list()
# Out:
# ['cpf',
#  'nome',
#  'sexo',
#  'grupo',
#  'vacina',
#  'lote',
#  'dose',
#  'data_vacinacao',
#  'local_vacinacao']

# %%
url
# Out:
#                     cpf                           nome       sexo  \
# 0        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 1        ***.574.544-**      AABAN VASCONCELOS ZYZZYAG  MASCULINO
# 2        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 3        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# 4        ***.886.964-**  AAMANDA MARIA FREIRE DA SILVA   FEMININO
# ...                 ...                            ...        ...
# 3407293  ***.619.454-**     NECIRA FERREIRA DE SANTANA   FEMININO
# 3407294  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407295  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407296  ***.705.064-**     SEVERINO MANOEL DE SANTANA  MASCULINO
# 3407297             NaN                            NaN        NaN
#
#                                          grupo  \
# 0        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# 1        TRABALHADORES INDUSTRIAIS E BANCÁRIOS
# ...

# %%
#quantas mulheres foram vacinadas?
selecao2 = url2 ["sexo"] == "FEMININO"
mulheres_unicas = url[selecao2][["nome", "sexo"]]
mulheres_unicas
# Out:
#                                                     nome      sexo
# 2                          AAMANDA MARIA FREIRE DA SILVA  FEMININO
# 3                          AAMANDA MARIA FREIRE DA SILVA  FEMININO
# 4                          AAMANDA MARIA FREIRE DA SILVA  FEMININO
# 5                  AANA JULIA RAMOS SOARES DE BRITO LIRA  FEMININO
# 6                  AANA JULIA RAMOS SOARES DE BRITO LIRA  FEMININO
# ...                                                  ...       ...
# 3407285  ZYNARA DE FATIMA FONSECA BACALHAU BOLD DA SILVA  FEMININO
# 3407286  ZYNARA DE FATIMA FONSECA BACALHAU BOLD DA SILVA  FEMININO
# 3407291                       NECIRA FERREIRA DE SANTANA  FEMININO
# 3407292                       NECIRA FERREIRA DE SANTANA  FEMININO
# 3407293                       NECIRA FERREIRA DE SANTANA  FEMININO
#
# [1941977 rows x 2 columns]

# %%
ms = mulheres_unicas.drop_duplicates()#exclui dados que são repetidos
ms
# Out:
#                                                     nome      sexo
# 2                          AAMANDA MARIA FREIRE DA SILVA  FEMININO
# 5                  AANA JULIA RAMOS SOARES DE BRITO LIRA  FEMININO
# 7                       AANA MAYARA DA SILVA DE OLIVEIRA  FEMININO
# 9                       AANDRESSA VASCONCELOS DOS SANTOS  FEMININO
# 59                              ABAGELVA VIEIRA DA CUNHA  FEMININO
# ...                                                  ...       ...
# 3407275       ZYELANYA CARINA CASSIMIRO DOS SANTOS ALVES  FEMININO
# 3407277                         ZYGINTA GIMBUTYTE CABRAL  FEMININO
# 3407279                               ZYMARA TENÓRIO VAZ  FEMININO
# 3407284  ZYNARA DE FATIMA FONSECA BACALHAU BOLD DA SILVA  FEMININO
# 3407291                       NECIRA FERREIRA DE SANTANA  FEMININO
#
# [769665 rows x 2 columns]

# %%
feminino = ms["sexo"]
masculino = hs["sexo"]

# %%
feminino
# Out:
# 2          FEMININO
# 5          FEMININO
# 7          FEMININO
# 9          FEMININO
# 59         FEMININO
#              ...
# 3407275    FEMININO
# 3407277    FEMININO
# 3407279    FEMININO
# 3407284    FEMININO
# 3407291    FEMININO
# Name: sexo, Length: 769665, dtype: object

# %%
interesses = [feminino.value_counts(),masculino.value_counts()]
i = pd.DataFrame(interesses)
i.plot(kind="bar")# KIND tipo do grafico e BAR o grafico usado
# Out:
# <Axes: >

# %%
i.plot(kind="bar", xlabel="sexos", ylabel="Quantidade de Pessoas Vacinadas", title="Comparação Vacinados")#plot é a impressão do grafico
# Out:
# <Axes: title={'center': 'Comparação Vacinados'}, xlabel='sexos', ylabel='Quantidade de Pessoas Vacinadas'>

# %%
vc1 = url.loc[url["dose"] == 1.0].count()
vc1
# Out:
# cpf                1516193
# nome               1519688
# sexo               1519602
# grupo              1519688
# vacina             1519688
# lote               1519618
# dose               1519688
# data_vacinacao     1519688
# local_vacinacao    1519688
# dtype: int64

# %%
vc2 = url.loc[url["dose"] == 2.0].count()
vc2
# Out:
# cpf                1311863
# nome               1312330
# sexo               1312241
# grupo              1312330
# vacina             1312330
# lote               1312315
# dose               1312330
# data_vacinacao     1312330
# local_vacinacao    1312330
# dtype: int64

# %%
vc3 = url.loc[url["dose"] == 3.0].count()
vc3
# Out:
# cpf                574253
# nome               574350
# sexo               574270
# grupo              574350
# vacina             574350
# lote               574342
# dose               574350
# data_vacinacao     574350
# local_vacinacao    574350
# dtype: int64

# %%
doses = url.dose.value_counts()
doses.plot(kind = "bar", color = "b")
plt.title("Quantidade de aplicações de cada dose")
plt.xlabel("Doses")
plt.ylabel("Quantidade")
plt.show()

# %%
#O VALOR EXATO DE CADA DOSE
doses
# Out:
# dose
# 1.0    1519688
# 2.0    1312330
# 3.0     574350
# 4.0        929
# Name: count, dtype: int64

# %%
tipos_de_grupo = pd.DataFrame(url.grupo.value_counts())
tipos_de_grupo
# Out:
#                                                       count
# grupo
# PÚBLICO EM GERAL (18 a 59 anos)                     1597108
# IDOSOS                                               782674
# TRABALHADORES DA SAÚDE                               302899
# PESSOAS COM COMORBIDADES                             181894
#  PÚBLICO EM GERAL - MENOR DE 18 ANOS                 160520
# TRABALHADORES DA EDUCAÇÃO                            122576
# CRIANÇAS DE 05 A 11 ANOS                              60399
# PÚBLICO EM GERAL - MENOR DE 18 ANOS                   53459
# GESTANTES E PUÉRPERAS                                 31957
# OUTRAS PRIORIDADES                                    29787
# TRABALHADORES INDUSTRIAIS E BANCÁRIOS                 25808
# CAMINHONEIROS                                         13009
# SESAU - BUSCA ATIVA                                    9914
# TRABALHADORES DA LIMPEZA URBANA                        6294
# TRABALHADORES DE TRANSPORTE AÉREO                      6261
# ...

# %%
tipos_de_grupo = url.grupo.value_counts()
plt.pie(tipos_de_grupo)#tipo do gráfico
plt.title("Grafico por Grupo")
plt.legend(url.grupo.value_counts().index,bbox_to_anchor=(1,1))#
plt.show()

# %%
url.grupo.value_counts().index
# Out:
# Index(['PÚBLICO EM GERAL (18 a 59 anos)', 'IDOSOS', 'TRABALHADORES DA SAÚDE',
#        'PESSOAS COM COMORBIDADES', ' PÚBLICO EM GERAL - MENOR DE 18 ANOS',
#        'TRABALHADORES DA EDUCAÇÃO', 'CRIANÇAS DE 05 A 11 ANOS',
#        'PÚBLICO EM GERAL - MENOR DE 18 ANOS', 'GESTANTES E PUÉRPERAS',
#        'OUTRAS PRIORIDADES', 'TRABALHADORES INDUSTRIAIS E BANCÁRIOS',
#        'CAMINHONEIROS', 'SESAU - BUSCA ATIVA',
#        'TRABALHADORES DA LIMPEZA URBANA', 'TRABALHADORES DE TRANSPORTE AÉREO',
#        'TRABALHADORES DE TRANSPORTE COLETIVO RODOVIÁRIO',
#        'TRABALHADORES DE TRANSPORTE METROVIÁRIO E FERROVIÁRIO',
#        'PESSOAS EM SITUAÇÃO DE RUA', 'TRABALHADORES PORTUÁRIOS',
#        'PESSOAS COM COMORBIDADES - 12 A 17 ANOS',
#        'PESSOAS COM DEFICIÊNCIA - 12 A 17 ANOS',
#        'CRIANÇAS DE 05 A 11 ANOS - Prioritárias',
#        'TRABALHADORES DA ASSISTÊNCIA SOCIAL',
#        'GESTANTES E PUÉRPERAS NÃO RESIDENTES EM RECIFE',
# ...
