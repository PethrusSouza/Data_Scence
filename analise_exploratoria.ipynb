# %% [markdown]
# <a href="https://colab.research.google.com/github/PethrusSouza/Data_Scence/blob/main/analise_exploratoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-talk')# Um estilo pronto para criar um gráfico
# Out:
# <ipython-input-18-23e17e05ed7b>:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-talk')# Um estilo pronto para criar um gráfico

# %%
dados = pd.read_csv('Dados-Pesquisa.csv')
# Out:
# <ipython-input-19-ad9ed8579afd>:1: DtypeWarning: Columns (21,57) have mixed types. Specify dtype option on import or set low_memory=False.
#   dados = pd.read_csv('Dados-Pesquisa.csv')

# %%
dados.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
dados.shape # quantidade linhas e colunas
# Out:
# (15620, 113)

# %%
dados.columns.to_list() # nomes das colunas
# Out:
# ['Age',
#  'AttendedBootcamp',
#  'BootcampFinish',
#  'BootcampFullJobAfter',
#  'BootcampLoanYesNo',
#  'BootcampMonthsAgo',
#  'BootcampName',
#  'BootcampPostSalary',
#  'BootcampRecommend',
#  'ChildrenNumber',
#  'CityPopulation',
#  'CodeEventBootcamp',
#  'CodeEventCoffee',
#  'CodeEventConferences',
#  'CodeEventDjangoGirls',
#  'CodeEventGameJam',
#  'CodeEventGirlDev',
#  'CodeEventHackathons',
#  'CodeEventMeetup',
#  'CodeEventNodeSchool',
#  'CodeEventNone',
#  'CodeEventOther',
#  'CodeEventRailsBridge',
#  'CodeEventRailsGirls',
#  'CodeEventStartUpWknd',
#  'CodeEventWomenCode',
#  'CodeEventWorkshop',
#  'CommuteTime',
#  'CountryCitizen',
#  'CountryLive',
#  'EmploymentField',
#  'EmploymentFieldOther',
#  'EmploymentStatus',
#  'EmploymentStatusOther',
#  'ExpectedEarning',
#  'FinanciallySupporting',
#  'Gender',
#  'HasChildren',
#  'HasDebt',
#  'HasFinancialDependents',
#  'HasHighSpdInternet',
#  'HasHomeMortgage',
#  'HasServedInMilitary',
# ...

# %%
df2 = dados.copy() # copia do dataframe

# %%
dados.isna().sum() # quantidade de dados nulos por coluna
# Out:
# Age                      2007
# AttendedBootcamp          240
# BootcampFinish          14687
# BootcampFullJobAfter    14985
# BootcampLoanYesNo       14686
#                         ...
# ResourceW3Schools       15499
# ResourceYouTube         15499
# SchoolDegree             1941
# SchoolMajor              7170
# StudentDebtOwe          12106
# Length: 113, dtype: int64

# %%
dados.isna().sum().sum() # quantidade de dados nulos em todas as colunas
# Out:
# 1183960

# %%
dados.dropna(subset = ["Age"], inplace=True)

# %%
dados.isna().sum()
# Out:
# Age                         0
# AttendedBootcamp          112
# BootcampFinish          12809
# BootcampFullJobAfter    13068
# BootcampLoanYesNo       12805
#                         ...
# ResourceW3Schools       13508
# ResourceYouTube         13506
# SchoolDegree              113
# SchoolMajor              5265
# StudentDebtOwe          10121
# Length: 113, dtype: int64

# %%
dados.isna().sum().sum()
# Out:
# 994859

# %%
dados.isna().mean() # porcentagem de dados nulos por coluna
# Out:
# Age                     0.000000
# AttendedBootcamp        0.008227
# BootcampFinish          0.940939
# BootcampFullJobAfter    0.959965
# BootcampLoanYesNo       0.940645
#                           ...
# ResourceW3Schools       0.992287
# ResourceYouTube         0.992140
# SchoolDegree            0.008301
# SchoolMajor             0.386763
# StudentDebtOwe          0.743480
# Length: 113, dtype: float64

# %%
print(f"A base de dados apresenta {dados.shape[0]} linhas e {dados.shape[1]}")
# Out:
# A base de dados apresenta 13613 linhas e 113

# %%
dados.dtypes.value_counts()
# Out:
# float64    85
# object     28
# Name: count, dtype: int64

# %%
# Criando um novo Data Frame apenas com as colunas que queremos:
dados = dados[["Age", "Gender", "JobPref", "JobRoleInterest", "EmploymentField", "JobRelocateYesNo", "HoursLearning", "MoneyForLearning"]]
dados
# Out:
#         Age  Gender                          JobPref  \
# 0      28.0    male                       freelance
# 1      22.0    male               work for a startup
# 2      19.0    male          start your own business
# 3      26.0  female               work for a startup
# 4      20.0  female  work for a medium-sized company
# ...     ...     ...                              ...
# 15615  39.0    male          start your own business
# 15616  27.0    male               work for a startup
# 15617  37.0    male                       freelance
# 15618  26.0    male                              NaN
# 15619  22.0  female                       freelance
#
#                  JobRoleInterest                        EmploymentField  \
# 0                            NaN      office and administrative support
# 1        Front-End Web Developer                      food and beverage
# 2                            NaN                                finance
# ...

# %%
dados = dados.drop_duplicates() # removendo linhas duplicadas
dados
# Out:
#         Age  Gender                          JobPref  \
# 0      28.0    male                       freelance
# 1      22.0    male               work for a startup
# 2      19.0    male          start your own business
# 3      26.0  female               work for a startup
# 4      20.0  female  work for a medium-sized company
# ...     ...     ...                              ...
# 15615  39.0    male          start your own business
# 15616  27.0    male               work for a startup
# 15617  37.0    male                       freelance
# 15618  26.0    male                              NaN
# 15619  22.0  female                       freelance
#
#                  JobRoleInterest                        EmploymentField  \
# 0                            NaN      office and administrative support
# 1        Front-End Web Developer                      food and beverage
# 2                            NaN                                finance
# ...

# %%
dados.shape
# Out:
# (12234, 8)

# %%
#resumo estatístico do Datset
dados.describe()
# Out:
#                 Age  JobRelocateYesNo  HoursLearning  MoneyForLearning
# count  12234.000000       4669.000000   11807.000000      11643.000000
# mean      29.598823          0.733348      15.713814       1193.690114
# std        9.215518          0.442256      14.548388       4999.765832
# min       10.000000          0.000000       0.000000          0.000000
# 25%       23.000000          0.000000       5.000000          0.000000
# 50%       28.000000          1.000000      10.000000         50.000000
# 75%       34.000000          1.000000      20.000000        400.000000
# max       86.000000          1.000000     100.000000     180000.000000

# %%
#Quando o parâmetro include é especificado com  "O"
#a função describe() incluirá estatística descretiva para #colunas que contenham valores de objeto,
#ou seja, colunas que comtêm strings ou outros tipos de dados não numéricos.

# %%
dados.describe(include='O')
# Out:
#        Gender                          JobPref           JobRoleInterest  \
# count   12194                             9320                      5552
# unique      5                                5                         9
# top      male  work for a medium-sized company  Full-Stack Web Developer
# freq     9360                             2841                      2211
#
#                     EmploymentField
# count                          6683
# unique                           15
# top     software development and IT
# freq                           3473

# %%
dados.loc[dados["Age"]>30]
# Out:
#         Age  Gender                  JobPref JobRoleInterest  \
# 5      34.0    male  start your own business             NaN
# 7      35.0    male               freelance              NaN
# 8      33.0    male                      NaN             NaN
# 9      33.0    male  start your own business             NaN
# 10     57.0    male               freelance              NaN
# ...     ...     ...                      ...             ...
# 15611  37.0    male  start your own business             NaN
# 15612  45.0  female  start your own business             NaN
# 15614  47.0    male               freelance              NaN
# 15615  39.0    male  start your own business             NaN
# 15617  37.0    male               freelance              NaN
#
#                          EmploymentField  JobRelocateYesNo  HoursLearning  \
# 5                                finance               NaN            5.0
# 7      office and administrative support               NaN            NaN
# ...

# %%
#ANALISE DE DADOS

# %%
dados["Age"].unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68., 86., 10.,
#        67., 72.])

# %%
dados.Age.unique()
# Out:
# array([28., 22., 19., 26., 20., 34., 23., 35., 33., 57., 27., 47., 37.,
#        31., 29., 30., 32., 25., 44., 21., 24., 18., 39., 41., 43., 36.,
#        40., 38., 16., 46., 15., 14., 50., 49., 45., 55., 51., 17., 53.,
#        52., 48., 56., 42., 54., 58., 65., 59., 75., 61., 80., 62., 60.,
#        66., 12., 11., 13., 63., 64., 70., 73., 69., 71., 68., 86., 10.,
#        67., 72.])

# %%
#qual a distribuição de idade dos participantes da pesquisa?
# Varriável Age
idade = dados.Age #dados["age"]
idade
# Out:
# 0        28.0
# 1        22.0
# 2        19.0
# 3        26.0
# 4        20.0
#          ...
# 15615    39.0
# 15616    27.0
# 15617    37.0
# 15618    26.0
# 15619    22.0
# Name: Age, Length: 12234, dtype: float64

# %%
#histograma
plt.hist(idade, label="Idades", color="lightseagreen")
plt.title("Distribuição de Idade")
plt.xlabel("Idade")
plt.ylabel("Quantidade")
plt.legend()
plt.grid(True)
plt.show()

# %%
#ANALISE DE GÊNERO

# %%
dados.Gender.value_counts()
# Out:
# Gender
# male           9360
# female         2697
# genderqueer      65
# agender          36
# trans            36
# Name: count, dtype: int64

# %%
dados.Gender.value_counts().sum()
# Out:
# 12194

# %%
tipos_de_genero = pd.DataFrame(dados.Gender.value_counts())
tipos_de_genero
# Out:
#              count
# Gender
# male          9360
# female        2697
# genderqueer     65
# agender         36
# trans           36

# %%
tipos_de_genero.head()
# Out:
#              count
# Gender
# male          9360
# female        2697
# genderqueer     65
# agender         36
# trans           36

# %%
tipos_de_genero.columns.name = "Tipo"

# %%
tipos_de_genero.head()
# Out:
# Tipo         count
# Gender
# male          9360
# female        2697
# genderqueer     65
# agender         36
# trans           36

# %%
tipos_de_genero.iloc[0]# pesquisa por indice, no caso o indice 0
# Out:
# Tipo
# count    9360
# Name: male, dtype: int64

# %%
#selecionando linha famele e tirando a porcentagem
feminino = tipos_de_genero.iloc[1]
feminino
# Out:
# Tipo
# count    2697
# Name: female, dtype: int64

# %%
total_genero = dados.Gender.value_counts().sum()
total_genero
# Out:
# 12194
